# %%
import pandas as pd

# %%
array=pd.Series()

# %%
array
# Out:
# Series([], dtype: object)

# %%
array=pd.Series(data=[[3,4],'t','u','i'])

# %%
array
# Out:
# 0    [3, 4]
# 1         t
# 2         u
# 3         i
# dtype: object

# %%
array[1:3]
# Out:
# 1    t
# 2    u
# dtype: object

# %%
data=[[11,'a'],[3,'t']]

# %%
array2=pd.DataFrame(data)
array2
# Out:
#     0  1
# 0  11  a
# 1   3  t

# %%
array=pd.read_csv('test.csv',sep=',')

# %%
type(array)
# Out:
# pandas.core.frame.DataFrame

# %%
array[1:]
# Out:
#     InvoiceNo StockCode                         Description  Quantity  \
# 1      581214     22086     PAPER CHAIN KIT 50'S CHRISTMAS         40
# 2      581214     21914              BLUE HARMONICA IN BOX         12
# 3      581214     21791  VINTAGE HEADS AND TAILS CARD GAME         12
# 4      581214     21790                  VINTAGE SNAP CARDS        12
# 5      581215     20983  12 PENCILS TALL TUBE RED RETROSPOT        24
# ..        ...       ...                                 ...       ...
# 149    581230     22899        CHILDREN'S APRON DOLLY GIRL          6
# 150    581230     23390            DOLLY GIRL MINI BACKPACK         4
# 151    581230     23389              SPACEBOY MINI BACKPACK         4
# 152    581230     22629                 SPACEBOY LUNCH BOX         12
# 153    581230     22367     CHILDRENS APRON SPACEBOY DESIGN         8
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
array.columns.values[1]='id'

# %%
# Out:
# Index(['InvoiceNo', 'id', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
array
# Out:
#     InvoiceNo     id                         Description  Quantity  \
# 0      581214  22144      CHRISTMAS CRAFT LITTLE FRIENDS        12
# 1      581214  22086     PAPER CHAIN KIT 50'S CHRISTMAS         40
# 2      581214  21914              BLUE HARMONICA IN BOX         12
# 3      581214  21791  VINTAGE HEADS AND TAILS CARD GAME         12
# 4      581214  21790                  VINTAGE SNAP CARDS        12
# ..        ...    ...                                 ...       ...
# 149    581230  22899        CHILDREN'S APRON DOLLY GIRL          6
# 150    581230  23390            DOLLY GIRL MINI BACKPACK         4
# 151    581230  23389              SPACEBOY MINI BACKPACK         4
# 152    581230  22629                 SPACEBOY LUNCH BOX         12
# 153    581230  22367     CHILDRENS APRON SPACEBOY DESIGN         8
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0    2011-12-08 08:32:00       2.10     14251.0  United Kingdom
# ...

# %%
array.dtypes
# Out:
# InvoiceNo       object
# id              object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
array=pd.read_csv('test.csv',sep=',')

# %%
array.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
array.query('Quantity<10')
# Out:
#     InvoiceNo StockCode                      Description  Quantity  \
# 13     581216     48187              DOORMAT NEW ENGLAND         4
# 14     581216     48194                   DOORMAT HEARTS         4
# 15     581216     48185               DOORMAT FAIRY CAKE         4
# 16     581216     23283             DOORMAT VINTAGE LEAF         2
# 17     581216     48129                  DOORMAT TOPIARY         2
# ..        ...       ...                              ...       ...
# 145    581230     22617       BAKING SET SPACEBOY DESIGN         3
# 149    581230     22899     CHILDREN'S APRON DOLLY GIRL          6
# 150    581230     23390         DOLLY GIRL MINI BACKPACK         4
# 151    581230     23389           SPACEBOY MINI BACKPACK         4
# 153    581230     22367  CHILDRENS APRON SPACEBOY DESIGN         8
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 13   2011-12-08 09:06:00       8.25     16523.0  United Kingdom
# ...

# %%
array.query('Quantity == (3,6)')
# Out:
#     InvoiceNo StockCode                          Description  Quantity  \
# 43     581218     23552         BICYCLE PUNCTURE REPAIR KIT          6
# 59     581219     22592        CARDHOLDER HOLLY WREATH METAL         3
# 64     581219     22599          CHRISTMAS MUSICAL ZINC STAR         6
# 96     581223     23239    SET OF 4 KNICK KNACK TINS POPPIES         6
# 97     581224     23552         BICYCLE PUNCTURE REPAIR KIT          6
# 101    581224     21485     RETROSPOT HEART HOT WATER BOTTLE         3
# 106    581224     21051                       RIBBONS PURSE          6
# 127    581227     23562  SET OF 6 RIBBONS PERFECTLY PRETTY           6
# 128    581227     22139     RETROSPOT TEA SET CERAMIC 11 PC          6
# 145    581230     22617           BAKING SET SPACEBOY DESIGN         3
# 149    581230     22899         CHILDREN'S APRON DOLLY GIRL          6
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
array
# Out:
#     InvoiceNo StockCode                         Description  Quantity  \
# 0      581214     22144      CHRISTMAS CRAFT LITTLE FRIENDS        12
# 1      581214     22086     PAPER CHAIN KIT 50'S CHRISTMAS         40
# 2      581214     21914              BLUE HARMONICA IN BOX         12
# 3      581214     21791  VINTAGE HEADS AND TAILS CARD GAME         12
# 4      581214     21790                  VINTAGE SNAP CARDS        12
# ..        ...       ...                                 ...       ...
# 149    581230     22899        CHILDREN'S APRON DOLLY GIRL          6
# 150    581230     23390            DOLLY GIRL MINI BACKPACK         4
# 151    581230     23389              SPACEBOY MINI BACKPACK         4
# 152    581230     22629                 SPACEBOY LUNCH BOX         12
# 153    581230     22367     CHILDRENS APRON SPACEBOY DESIGN         8
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
check=array.isnull().sum()
check
# Out:
# InvoiceNo       0
# StockCode       0
# Description     0
# Quantity        0
# InvoiceDate     0
# UnitPrice       0
# CustomerID     19
# Country         0
# dtype: int64

# %%
array['CustomerID'].count()
# Out:
# 135

# %%
arrayGroup=array.groupby(by='CustomerID',as_index=False).count()

# %%
print(arrayGroup)
# Out:
#     CustomerID  InvoiceNo  StockCode  Description  Quantity  InvoiceDate  \
# 0      12558.0         11         11           11        11           11
# 1      13408.0          8          8            8         8            8
# 2      13924.0         13         13           13        13           13
# 3      14191.0         13         13           13        13           13
# 4      14251.0          5          5            5         5            5
# 5      14291.0          9          9            9         9            9
# 6      14520.0          3          3            3         3            3
# 7      15237.0          7          7            7         7            7
# 8      16019.0          5          5            5         5            5
# 9      16523.0         24         24           24        24           24
# 10     17631.0         10         10           10        10           10
# 11     17677.0         21         21           21        21           21
# ...

# %%
arrayGroup.count()
# Out:
# CustomerID     13
# InvoiceNo      13
# StockCode      13
# Description    13
# Quantity       13
# InvoiceDate    13
# UnitPrice      13
# Country        13
# dtype: int64

# %%
result = arrayGroup[['CustomerID', 'InvoiceNo']]
result
# Out:
#     CustomerID  InvoiceNo
# 0      12558.0         11
# 1      13408.0          8
# 2      13924.0         13
# 3      14191.0         13
# 4      14251.0          5
# 5      14291.0          9
# 6      14520.0          3
# 7      15237.0          7
# 8      16019.0          5
# 9      16523.0         24
# 10     17631.0         10
# 11     17677.0         21
# 12     17856.0          6

# %%
array2=pd.read_csv('test.csv',sep=',')

# %%
array2
# Out:
#     InvoiceNo StockCode                         Description  Quantity  \
# 0      581214     22144      CHRISTMAS CRAFT LITTLE FRIENDS        12
# 1      581214     22086     PAPER CHAIN KIT 50'S CHRISTMAS         40
# 2      581214     21914              BLUE HARMONICA IN BOX         12
# 3      581214     21791  VINTAGE HEADS AND TAILS CARD GAME         12
# 4      581214     21790                  VINTAGE SNAP CARDS        12
# ..        ...       ...                                 ...       ...
# 149    581230     22899        CHILDREN'S APRON DOLLY GIRL          6
# 150    581230     23390            DOLLY GIRL MINI BACKPACK         4
# 151    581230     23389              SPACEBOY MINI BACKPACK         4
# 152    581230     22629                 SPACEBOY LUNCH BOX         12
# 153    581230     22367     CHILDRENS APRON SPACEBOY DESIGN         8
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
import pandas as pd

# Path to the large CSV file
file_path = 'test.csv'

# Define the chunk size
chunk_size = 60 # Set a small chunk size for demonstration

# Initialize an empty DataFrame to store the concatenated chunks
result_df = pd.DataFrame()

# Iterate over chunks and process each chunk
for chunk in pd.read_csv(file_path, chunksize=chunk_size):
    # Perform operations on each chunk if needed
    # For example, calculate the average Value for each chunk
    avg_value = chunk['Quantity'].count()

    # Print the result for each chunk
    print(f"Average Value for this chunk: {avg_value}")
    

    # Concatenate the processed chunk to the result DataFrame
    result_df = pd.concat([result_df, chunk], ignore_index=True)

# Now, result_df contains the entire dataset, and you can continue processing the combined data if needed
print("\nCombined DataFrame:")
print(result_df)
# Out:
# Average Value for this chunk: 60
# Average Value for this chunk: 60
# Average Value for this chunk: 34
#
# Combined DataFrame:
#     InvoiceNo StockCode                         Description  Quantity  \
# 0      581214     22144      CHRISTMAS CRAFT LITTLE FRIENDS        12
# 1      581214     22086     PAPER CHAIN KIT 50'S CHRISTMAS         40
# 2      581214     21914              BLUE HARMONICA IN BOX         12
# 3      581214     21791  VINTAGE HEADS AND TAILS CARD GAME         12
# 4      581214     21790                  VINTAGE SNAP CARDS        12
# ..        ...       ...                                 ...       ...
# 149    581230     22899        CHILDREN'S APRON DOLLY GIRL          6
# 150    581230     23390            DOLLY GIRL MINI BACKPACK         4
# 151    581230     23389              SPACEBOY MINI BACKPACK         4
# 152    581230     22629                 SPACEBOY LUNCH BOX         12
# 153    581230     22367     CHILDRENS APRON SPACEBOY DESIGN         8
#
# ...

# %%
array=result_df

# %%
array.iloc[[1,2],[1,2]]
# Out:
#   StockCode                      Description
# 1     22086  PAPER CHAIN KIT 50'S CHRISTMAS
# 2     21914           BLUE HARMONICA IN BOX

# %%
array.iloc[[1,2],[0,1]]
# Out:
#   InvoiceNo StockCode
# 1    581214     22086
# 2    581214     21914

# %%
import json

# %%
import json

# Open the JSON Lines file in read ('r') mode
with open('test.json', 'r') as file:
    # Read all lines from the file and parse each JSON object
    data_list = [json.loads(line) for line in file]

# Now 'data_list' is a list containing the parsed JSON objects
print(data_list)
# Out:
# [{'ORIGIN_COUNTRY_NAME': 'Saint Martin', 'DEST_COUNTRY_NAME': 'United States', 'count': 1}, {'ORIGIN_COUNTRY_NAME': 'Romania', 'DEST_COUNTRY_NAME': 'United States', 'count': 12}, {'ORIGIN_COUNTRY_NAME': 'Croatia', 'DEST_COUNTRY_NAME': 'United States', 'count': 2}, {'ORIGIN_COUNTRY_NAME': 'Ireland', 'DEST_COUNTRY_NAME': 'United States', 'count': 291}, {'ORIGIN_COUNTRY_NAME': 'India', 'DEST_COUNTRY_NAME': 'United States', 'count': 62}, {'ORIGIN_COUNTRY_NAME': 'United States', 'DEST_COUNTRY_NAME': 'Egypt', 'count': 11}, {'ORIGIN_COUNTRY_NAME': 'Grenada', 'DEST_COUNTRY_NAME': 'United States', 'count': 47}, {'ORIGIN_COUNTRY_NAME': 'United States', 'DEST_COUNTRY_NAME': 'Costa Rica', 'count': 529}, {'ORIGIN_COUNTRY_NAME': 'United States', 'DEST_COUNTRY_NAME': 'Senegal', 'count': 35}, {'ORIGIN_COUNTRY_NAME': 'Sint Maarten', 'DEST_COUNTRY_NAME': 'United States', 'count': 290}, {'ORIGIN_COUNTRY_NAME': 'United States', 'DEST_COUNTRY_NAME': 'Guyana', 'count': 52}, {'ORIGIN_COUNTRY_NAME': 'Marsha
# ...

# %%
df=pd.DataFrame(data_list)
df
# Out:
#        ORIGIN_COUNTRY_NAME                  DEST_COUNTRY_NAME  count
# 0             Saint Martin                      United States      1
# 1                  Romania                      United States     12
# 2                  Croatia                      United States      2
# 3                  Ireland                      United States    291
# 4                    India                      United States     62
# ..                     ...                                ...    ...
# 236          French Guiana                      United States      4
# 237  Saint Kitts and Nevis                      United States    123
# 238                  Haiti                      United States    193
# 239          United States  Bonaire, Sint Eustatius, and Saba     62
# 240          United States                             Greece     20
#
# [241 rows x 3 columns]

# %%
array2=pd.read_json('test.json')
array2
# Out:
#    ORIGIN_COUNTRY_NAME DEST_COUNTRY_NAME  count
# 0         Saint Martin     United States      1
# 1              Romania     United States     12
# 2              Croatia     United States      2
# 3              Ireland     United States    291
# 4                India     United States     62
# ..                 ...               ...    ...
# 76       United States            Sweden     94
# 77              Kuwait     United States     24
# 78  Dominican Republic     United States   1282
# 79               Egypt     United States     11
# 80       United States            Israel    108
#
# [81 rows x 3 columns]

# %%
arra3=pd.read_json('testnew.json',lines=True,orient='records')

# %%
arra3
# Out:
#        ORIGIN_COUNTRY_NAME                  DEST_COUNTRY_NAME  count
# 0                  Romania                      United States     15
# 1                  Croatia                      United States      1
# 2                  Ireland                      United States    344
# 3            United States                              Egypt     15
# 4                    India                      United States     62
# ..                     ...                                ...    ...
# 251  Saint Kitts and Nevis                      United States    145
# 252          United States                            Uruguay     43
# 253                  Haiti                      United States    225
# 254          United States  Bonaire, Sint Eustatius, and Saba     58
# 255          United States                             Greece     30
#
# [256 rows x 3 columns]

# %%
import pandas as pd

# JSON data


# Read JSON data into a DataFrame
df = pd.read_json('zz.json', orient='split')

# Display the resulting DataFrame
print(df)
# Out:
#    A    B
# 0  1  foo
# 1  2  bar
# 2  3  baz

# %%
import pandas as pd

# JSON data


# Read JSON data into a DataFrame
df = pd.read_json('test.json', orient='record')

# Display the resulting DataFrame
print(df)
# Out:
#    ORIGIN_COUNTRY_NAME DEST_COUNTRY_NAME  count
# 0         Saint Martin     United States      1
# 1              Romania     United States     12
# 2              Croatia     United States      2
# 3              Ireland     United States    291
# 4                India     United States     62
# ..                 ...               ...    ...
# 76       United States            Sweden     94
# 77              Kuwait     United States     24
# 78  Dominican Republic     United States   1282
# 79               Egypt     United States     11
# 80       United States            Israel    108
#
# [81 rows x 3 columns]

# %%
import pandas as pd

# JSON data


# Read JSON data into a DataFrame
df = pd.read_json('testnew.json', orient='record',lines=True)

# Display the resulting DataFrame
print(df)
# Out:
#        ORIGIN_COUNTRY_NAME                  DEST_COUNTRY_NAME  count
# 0                  Romania                      United States     15
# 1                  Croatia                      United States      1
# 2                  Ireland                      United States    344
# 3            United States                              Egypt     15
# 4                    India                      United States     62
# ..                     ...                                ...    ...
# 251  Saint Kitts and Nevis                      United States    145
# 252          United States                            Uruguay     43
# 253                  Haiti                      United States    225
# 254          United States  Bonaire, Sint Eustatius, and Saba     58
# 255          United States                             Greece     30
#
# [256 rows x 3 columns]

# %%
df.to_json('op.json',orient='split')

# %%
df.to_json('op2.json',orient='records',lines=True)

# %%
df.to_json('op3.json',orient='table')
